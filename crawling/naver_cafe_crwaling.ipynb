# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs
import csv 
import requests
import pandas as pd
import re
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import urllib.request
import random
import numpy as np
import os
import warnings 
warnings.filterwarnings(action='ignore') #경고 무시

# %%
#수집하고 싶은 기간
first_days = pd.date_range('2020/01/01', '2020/3/31', freq='MS') # MS는 해당 월 초 날짜 산출
last_days = pd.date_range('2020/01/01', '2020/3/31', freq='M') # M은 해당 월 말 날짜 산출
first_days
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01'], dtype='datetime64[ns]', freq='MS')

# %%
#첫번째 input으로 검색 키워드를 설정합니다 (e.g., "자동차")
keyword = input('키워드를 입력해주세요 :')

#url을 설정합니다
url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=article&query={}&oquery=&tqi=hiWMmlprvOsssNOIF04ssssssaK-465360'.format(keyword)

# 크롬 드라이버 선언
driver = webdriver.Chrome("chromedriver.exe") #"chromedriver.exe" 대신에 현재 컴퓨터의 크롬드라이버 위치가 들어가야 합니다
driver.implicitly_wait(1) # sleep()과 차이점은 sleep()은 지정된 시간 동안 무조건 기다리라는 뜻이고, 암시적 대기는 지정한 시간이 되기 전에 페이지 로드가 끝나면 다음 작업을 진행하라는 뜻

# 네이버 VIEW 카페 검색창 이동
driver.get(url)
time.sleep(1)

# 원하는 카페 개수를 10 단위로 입력 (스크롤 당 10개의 카페가 업로드 됩니다)
# 코드가 복잡하면 그냥 스크롤 횟수로 변경해도 무방할 것 같습니다
url_want = int(input('10단위로 원하는 카페 개수 입력 :'))

#10의 배수로 숫자를 입력하지 않은 경우 재입력을 받는 코드입니다
while url_want%10 !=0: 
    url_want = int(input('10단위로 원하는 카페 개수 입력 :'))
    if url_want%10 ==0:
         break
# Out:
# 키워드를 입력해주세요 :애플워치
# 10단위로 원하는 카페 개수 입력 :20

# %%
cafe_url_list=[]

# 검색 옵션 클릭하기
driver.find_element_by_xpath('//*[@id="snb"]/div[1]/div/div[2]/a').click()
for k in range(len(first_days)):
    # 접입력 클릭하기
    driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[4]/div/div[1]/a[9]').click()
    time.sleep(0.8)    

    #시작 날짜 지정
    #년(year) 클릭 
    driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[4]/div/div[2]/div[2]/div[1]/div/div/div/ul/li[{0}]/a'.format(first_days.year[k]-1989)).click()
    #월(momth) 클릭
    driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[4]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[{0}]/a'.format(first_days.month[k])).click()
    #일 (day) 클릭
    driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[4]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[{0}]/a'.format(first_days.day[k])).click()

    #끝 날짜 클릭
    driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[4]/div/div[2]/div[1]/span[3]/a').click()
    #년(year) 클릭 
    driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[4]/div/div[2]/div[2]/div[1]/div/div/div/ul/li[{0}]/a'.format(last_days.year[k]-1989)).click()
    #월(momth) 클릭
    driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[4]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[{0}]/a'.format(last_days.month[k])).click()
    #일 (day) 클릭
    driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[4]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[{0}]/a'.format(last_days.day[k])).click()
    
    #적용 버튼 클릭하기
    driver.find_element_by_xpath('//*[@id="snb"]/div[2]/ul/li[4]/div/div[2]/div[3]/button').click()
    
    #스크롤 위치 인식
    last_height = driver.execute_script("return document.body.scrollHeight") 

    #스크롤 횟수 (1회 스크롤당 게시물 10개 보입니다)
    scroll = (url_want/10)-1 
        
    #지정한 만큼 스크롤 다운
    for i in range(int(scroll)):                                                                  
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") #스크롤을 가능한 아래까지 내립니다.
        time.sleep(random.uniform(1,1.7)) #1초에서 1.7초 사이 랜덤으로 쉬어가기
        
        new_height = driver.execute_script("return document.body.scrollHeight")  #스크롤을 가능한 아래까지 내렸을 때, 갱신되어 스크롤의 위치와 크기가 바뀌면, 다시 그 스크롤을 최대한 아래까지 내립니다.
        if new_height == last_height:   
            break
            
        last_height = new_height
                                    
                                                                             
    # 카페 url 긁어오기
    soup = bs(driver.page_source, 'lxml') 
    cafe_url = soup.find_all('a',class_='api_txt_lines total_tit')
        
    # url 추출, 리스트에 정리
    for i in cafe_url:
        cafe_url_list.append(i['href'])
            
    print('{0}년{1}월'.format(first_days.year[k], first_days.month[k]), len(cafe_url),'개 카페 url주소 수집')

        
    #스크롤 맨위로    
    driver.execute_script("window.scrollTo(0, 0)")
    time.sleep(0.8)
# Out:
# 2020년1월 20 개 카페 url주소 수집
# 2020년2월 20 개 카페 url주소 수집
# 2020년3월 20 개 카페 url주소 수집

# %%
len(cafe_url_list)
# Out:
# 60

# %%
real_list = set(cafe_url_list)
cafe_url_list = list(real_list)
len(cafe_url_list)
# Out:
# 60

# %%
#url_list csv로 저장
k = pd.DataFrame(cafe_url_list)
k.to_csv('cafe_url_list.csv')

# %%
#csv로 저장한 url_list 불러오기
url = pd.read_csv('cafe_url_list.csv')
cafe_url_list = list(url['0'])
cafe_url_list
# Out:
# ['https://cafe.naver.com/as6060/1002332?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFzNjA2MCIsImFydGljbGVJZCI6MTAwMjMzMiwiaXNzdWVkQXQiOjE2NTAwMjA5MTEzOTh9.H3p2KndOV2Goa3NbsnqLTrKsjRU6pOhrCmRCBN9IcBM',
#  'https://cafe.naver.com/swimmingholicclub/353664?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN3aW1taW5naG9saWNjbHViIiwiYXJ0aWNsZUlkIjozNTM2NjQsImlzc3VlZEF0IjoxNjUwMDIwOTAzNDE0fQ.WsBBqarxb5c86fVr1qQxxrLt3ubFpCR7Y2-5PXWunX0',
#  'https://cafe.naver.com/appleiphone/5620489?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjIwNDg5LCJpc3N1ZWRBdCI6MTY1MDAyMDkwNzU1NX0.xYievdqQTye6HfO0_E2HcMiGKKLi6FY1uBtsjguSc1c',
#  'https://cafe.naver.com/swimmingholicclub/368837?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN3aW1taW5naG9saWNjbHViIiwiYXJ0aWNsZUlkIjozNjg4MzcsImlzc3VlZEF0IjoxNjUwMDIwOTA2ODE2fQ.Yy0NTBm6zur2r4DHZcCi051YVJi4jnYI3zCWqJDpjFU',
#  'https://cafe.naver.com/appleiphone/5639791?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjM5NzkxLCJpc3N1ZWRBdCI6MTY1MDAyMDkwNjgxNX0.nekiVN3LEqMqUC7XZmcnKfO0eKF59OEvXJieRrF68_o',
#  'https://cafe.naver.com/anycallusershow/3165306?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFueWNhbGx1c2Vyc2hvdyIsImFydGljbGVJZCI6MzE2NTMwNiwiaXNzdWVkQXQiOjE2NTAwMjA5MDY4MTh9.haI9_5y-n5yvYNjLE3_4kdcWSpH9cbhu1zISfk7nqO4',
#  'https://cafe.naver.com/appleiphone/5711953?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NzExOTUzLCJpc3N1ZWRBdCI6MTY1MDAyMDkxMTQwMn0.HBLmilsOR2iD71xKjmBrpLOCg83HI9HWofsGceVuKAY',
#  'https://cafe.naver.com/appleiphone/5686533?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1Njg2NTMzLCJpc3N1ZWRBdCI6MTY1MDAyMDkxMjA0NX0._fGWJv6BnjzFpvpQ4dCnpGIWsh2ReTaVtjmBrsj7XdA',
#  'https://cafe.naver.com/appleiphone/5661854?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjYxODU0LCJpc3N1ZWRBdCI6MTY1MDAyMDkxMTM5OX0.Yw-hMFCoUqnpdHb0BnqfrhDjjWTzF08XI27C-1W57Es',
#  'https://cafe.naver.com/watchholic/416479?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6IndhdGNoaG9saWMiLCJhcnRpY2xlSWQiOjQxNjQ3OSwiaXNzdWVkQXQiOjE2NTAwMjA5MDI1MDJ9.7iKrN0ddok0CaXimcSrpSyF3UayneahGEsAqLjE18QU',
#  'https://cafe.naver.com/appleiphone/5604449?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjA0NDQ5LCJpc3N1ZWRBdCI6MTY1MDAyMDkwNzU1OH0.Vhdy_Ic_WVezrjYGq1DCPP9cP_c53AagttgxcFHXXJU',
#  'https://cafe.naver.com/appleiphone/5672547?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjcyNTQ3LCJpc3N1ZWRBdCI6MTY1MDAyMDkxMTQwM30.82U1dyhPJ8ZbmWgWikySXO60dbqoGGS31AXC7UqzPUk',
#  'https://cafe.naver.com/swimmingholicclub/357283?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN3aW1taW5naG9saWNjbHViIiwiYXJ0aWNsZUlkIjozNTcyODMsImlzc3VlZEF0IjoxNjUwMDIwOTAyNTAwfQ.0gWgJ4fRjiPgGkg3kNGWGKmAqPnPqWs2NySLM2S19RE',
#  'https://cafe.naver.com/joonggonara/697458992?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Impvb25nZ29uYXJhIiwiYXJ0aWNsZUlkIjo2OTc0NTg5OTIsImlzc3VlZEF0IjoxNjUwMDIwOTAzNDA5fQ.LDBVR604Dgl62X4KPxKq_af7HkDsypM1yfBMp6dwKVk',
#  'https://cafe.naver.com/nyblog/408275?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Im55YmxvZyIsImFydGljbGVJZCI6NDA4Mjc1LCJpc3N1ZWRBdCI6MTY1MDAyMDkxMjA0Nn0.TY-9-O2Zby-z7E4MwjRTAPEfYgng7L7bI25qeSym4DU',
#  'https://cafe.naver.com/cosmania/28083462?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImNvc21hbmlhIiwiYXJ0aWNsZUlkIjoyODA4MzQ2MiwiaXNzdWVkQXQiOjE2NTAwMjA5MDM0MTZ9.r9_Ukn2dBpdUKeqagvd0t9-JYZ8NHlVnZ0u43o0ZUck',
#  'https://cafe.naver.com/appleiphone/5581618?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NTgxNjE4LCJpc3N1ZWRBdCI6MTY1MDAyMDkwMjUwNX0.VisnM-GTpZdw3vYgzxFbNE-xsRoSzsv8URWFYwEtODE',
#  'https://cafe.naver.com/swimmingholicclub/353922?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN3aW1taW5naG9saWNjbHViIiwiYXJ0aWNsZUlkIjozNTM5MjIsImlzc3VlZEF0IjoxNjUwMDIwOTAzNDE1fQ.8HfSkHPmuhT2TI4wT8sTNkGvTIteXzAqcBS59HUl958',
#  'https://cafe.naver.com/swimmingholicclub/360721?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN3aW1taW5naG9saWNjbHViIiwiYXJ0aWNsZUlkIjozNjA3MjEsImlzc3VlZEF0IjoxNjUwMDIwOTAyNTA0fQ.dMxfpaKCrGK_l_xhy_q2ZH9dKN7AutkFoQt9VjNOUdo',
#  'https://cafe.naver.com/inmacbook/2197708?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImlubWFjYm9vayIsImFydGljbGVJZCI6MjE5NzcwOCwiaXNzdWVkQXQiOjE2NTAwMjA5MDM0MTF9.ReuPNCy_fLfsgDRpeleaZg1NTwjZja1yYR6owepOSCU',
#  'https://cafe.naver.com/hotellife/1527698?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImhvdGVsbGlmZSIsImFydGljbGVJZCI6MTUyNzY5OCwiaXNzdWVkQXQiOjE2NTAwMjA5MDY4MTd9.Q5piN_r-xLl7_Q7wfwDvdqxP7QNxB7iuBXH58z7dccM',
#  'https://cafe.naver.com/swimmingholicclub/379325?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN3aW1taW5naG9saWNjbHViIiwiYXJ0aWNsZUlkIjozNzkzMjUsImlzc3VlZEF0IjoxNjUwMDIwOTA3NTU5fQ.iAC6L5shzlzQje0tKwAhHunu8P596G46pvw966PwBys',
#  'https://cafe.naver.com/ps3friend/1622030?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InBzM2ZyaWVuZCIsImFydGljbGVJZCI6MTYyMjAzMCwiaXNzdWVkQXQiOjE2NTAwMjA5MDY4MjB9.QuL6XzOJAIIpR7HBrFIs0_uaq31zQR7y1bQDdYhnDa0',
#  'https://cafe.naver.com/appleiphone/5676345?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1Njc2MzQ1LCJpc3N1ZWRBdCI6MTY1MDAyMDkxMTM5Nn0.iJRfzs5Q8bkBsIo_LOrQJ1eBxcGQ4Vd2vTmQZx6mVH4',
#  'https://cafe.naver.com/appleiphone/5709981?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NzA5OTgxLCJpc3N1ZWRBdCI6MTY1MDAyMDkxMjA0OH0.q6Jq5bcFMf_pMWKfkI5c5YkMI0h3omezXy-f7kJreac',
#  'https://cafe.naver.com/casuallydressed/239305?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImNhc3VhbGx5ZHJlc3NlZCIsImFydGljbGVJZCI6MjM5MzA1LCJpc3N1ZWRBdCI6MTY1MDAyMDkwNjgxOH0.YDkpbikbpAI-maCvXZgijKmnmNuTKvCFfJNCV8tJvyY',
#  'https://cafe.naver.com/appleiphone/5677576?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1Njc3NTc2LCJpc3N1ZWRBdCI6MTY1MDAyMDkxMjA0MX0.8MGFmzES89W0upcnMUrZSLBgmOCg4X7upKI52WybcWk',
#  'https://cafe.naver.com/appleiphone/5599619?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NTk5NjE5LCJpc3N1ZWRBdCI6MTY1MDAyMDkwMzQxMn0.RK8d0ntbHpXNjpZ64cayK8pILC9KVLzcSSFFxCwJufk',
#  'https://cafe.naver.com/appleiphone/5616150?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjE2MTUwLCJpc3N1ZWRBdCI6MTY1MDAyMDkwNzU1N30.AYYqUYNzRkdzZRyEqH_RMLIK1Aqzp2hLciQfXj2Cuk0',
#  'https://cafe.naver.com/casuallydressed/237536?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImNhc3VhbGx5ZHJlc3NlZCIsImFydGljbGVJZCI6MjM3NTM2LCJpc3N1ZWRBdCI6MTY1MDAyMDkwNjgxNH0.Xk6hZ10NRdpv4GH2FIf47U_polrpByxTNYpvS7wQEqE',
#  'https://cafe.naver.com/malltail/5381249?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Im1hbGx0YWlsIiwiYXJ0aWNsZUlkIjo1MzgxMjQ5LCJpc3N1ZWRBdCI6MTY1MDAyMDkwMjUwM30.TSzwOSumh0EExPTEPkf6CWpUXJivrZt6hEXsv7yLv00',
#  'https://cafe.naver.com/bimmerwerks/474479?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImJpbW1lcndlcmtzIiwiYXJ0aWNsZUlkIjo0NzQ0NzksImlzc3VlZEF0IjoxNjUwMDIwOTAzNDEwfQ.wptjO90RXsPMl1fcw8jd8Q9eyU6nh_yQyFK6FZXQ2yc',
#  'https://cafe.naver.com/appleiphone/5635066?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjM1MDY2LCJpc3N1ZWRBdCI6MTY1MDAyMDkwNzU1Nn0._ZzDjum4lJTqB0GN3t6ljwjgQsBVPRl0girds850Cjw',
#  'https://cafe.naver.com/sjmoms/1543343?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InNqbW9tcyIsImFydGljbGVJZCI6MTU0MzM0MywiaXNzdWVkQXQiOjE2NTAwMjA5MDY4MjB9.ILXFkgANcZMYUJUPH-5Ydfc3JGNiIavYtnWZUA0iTnE',
#  'https://cafe.naver.com/appleiphone/5594235?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NTk0MjM1LCJpc3N1ZWRBdCI6MTY1MDAyMDkwMjQ5OH0.ClP1sBs8y_m_nZTo538s8XkzBtJtGAJy6QEo0iMmHZg',
#  'https://cafe.naver.com/swimmingholicclub/367528?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN3aW1taW5naG9saWNjbHViIiwiYXJ0aWNsZUlkIjozNjc1MjgsImlzc3VlZEF0IjoxNjUwMDIwOTA3NTYyfQ.MsM25uNO1grkNlldzdLBguXf-5bxnxic2WF2LPuHOs0',
#  'https://cafe.naver.com/appleiphone/5708377?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NzA4Mzc3LCJpc3N1ZWRBdCI6MTY1MDAyMDkxMjA0NH0.9_2ECCcjZqPUXHaJJrdDXqDW1FN-zYVsgehRVl3WGss',
#  'https://cafe.naver.com/appleiphone/5652689?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjUyNjg5LCJpc3N1ZWRBdCI6MTY1MDAyMDkwNzU1N30.duWd27IThO_hdnxMBobgZaPSjTHboF9AOYgLI10JFYw',
#  'https://cafe.naver.com/2ndkalsuma/3472987?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6IjJuZGthbHN1bWEiLCJhcnRpY2xlSWQiOjM0NzI5ODcsImlzc3VlZEF0IjoxNjUwMDIwOTEyMDQ3fQ.ykELdtLysjfjXaQeGnT3DPZBgPBVD6gisueUHuU52Ns',
#  'https://cafe.naver.com/appleiphone/5697435?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1Njk3NDM1LCJpc3N1ZWRBdCI6MTY1MDAyMDkxMTM5M30.DTZfPkLYHk5L3Ya1nPOk06OtTZvnCMjivZFQ7O_H6Ds',
#  'https://cafe.naver.com/casuallydressed/233489?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImNhc3VhbGx5ZHJlc3NlZCIsImFydGljbGVJZCI6MjMzNDg5LCJpc3N1ZWRBdCI6MTY1MDAyMDkwNzU2MX0.1o5FzxxCiiYHQB5VEs0Pl5wCMUSR3U3Jh2DxlwAAs0U',
#  'https://cafe.naver.com/dieselmania/30089873?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImRpZXNlbG1hbmlhIiwiYXJ0aWNsZUlkIjozMDA4OTg3MywiaXNzdWVkQXQiOjE2NTAwMjA5MDc1NjJ9.ZDe6Q1W_KkEVPvryDJum6jBt8b5_JvYXUaJmn1K7HF4',
#  'https://cafe.naver.com/inmacbook/2233907?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImlubWFjYm9vayIsImFydGljbGVJZCI6MjIzMzkwNywiaXNzdWVkQXQiOjE2NTAwMjA5MTEzOTd9.wpFxjnRU3wqVYFU9BfM28AtAH2V4mi-d_NMFlFJFlRg',
#  'https://cafe.naver.com/appleiphone/5662498?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjYyNDk4LCJpc3N1ZWRBdCI6MTY1MDAyMDkxMjA0NH0.pGJMkfv90uxJmsUOU1trHVl5TZ19q9ZGwz9ErnCMgg0',
#  'https://cafe.naver.com/swimmingholicclub/394131?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN3aW1taW5naG9saWNjbHViIiwiYXJ0aWNsZUlkIjozOTQxMzEsImlzc3VlZEF0IjoxNjUwMDIwOTExMzk5fQ.Gwd7hfxZGlk1lfEqBHFyqZnFn-i70Y8ponANkIQC5H4',
#  'https://cafe.naver.com/nyblog/374978?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Im55YmxvZyIsImFydGljbGVJZCI6Mzc0OTc4LCJpc3N1ZWRBdCI6MTY1MDAyMDkwNjgxOX0.kIBH-JoMkJQ7uQymtt_LMg_gvEMNQDGQTsCnwMukQhk',
#  'https://cafe.naver.com/inmacbook/2252475?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImlubWFjYm9vayIsImFydGljbGVJZCI6MjI1MjQ3NSwiaXNzdWVkQXQiOjE2NTAwMjA5MTIwNDd9.xKhxPlP2xQ4eHc8Qpxn6SWy1cCznyADFY18RnyLV75s',
#  'https://cafe.naver.com/appleiphone/5601400?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjAxNDAwLCJpc3N1ZWRBdCI6MTY1MDAyMDkwNzU2MH0.MBRC3QW5xKKkE4p2pFqFkay7r2HEsfR-sTohngKrArA',
#  'https://cafe.naver.com/xst/401138?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InhzdCIsImFydGljbGVJZCI6NDAxMTM4LCJpc3N1ZWRBdCI6MTY1MDAyMDkwMjUwMn0.CuOHbvE8omozvCYU7BxbIwWrYarXcHUbSLAWc9xBL3M',
#  'https://cafe.naver.com/appleiphone/5586070?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NTg2MDcwLCJpc3N1ZWRBdCI6MTY1MDAyMDkwMjUwNH0.JZl6W3LFgO9rjmVan4iaW8LUUX3HlZEAOsP6CFGLGyk',
#  'https://cafe.naver.com/swimmingholicclub/350779?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN3aW1taW5naG9saWNjbHViIiwiYXJ0aWNsZUlkIjozNTA3NzksImlzc3VlZEF0IjoxNjUwMDIwOTAzNDE0fQ.PVao5NYfqYjLdjy5Zv-M86zOTr9YLqC7ocIbAUj79Gs',
#  'https://cafe.naver.com/joonggonara/722808405?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Impvb25nZ29uYXJhIiwiYXJ0aWNsZUlkIjo3MjI4MDg0MDUsImlzc3VlZEF0IjoxNjUwMDIwOTEyMDQwfQ.poz6zy1CrqMACmladyCvlT0mrvifSZBPNzG5m4fDpZg',
#  'https://cafe.naver.com/appleiphone/5688810?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1Njg4ODEwLCJpc3N1ZWRBdCI6MTY1MDAyMDkxMTQwMX0.VmFR4I7Bkz-H88aDFC7QdBZZgdS662cNO0upbRRmT3w',
#  'https://cafe.naver.com/appleiphone/5554255?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NTU0MjU1LCJpc3N1ZWRBdCI6MTY1MDAyMDkwMzQxMX0.aYh5Osk4gHvdn6feNVQBOPkYFhDWIppF6dB3FZoJkDU',
#  'https://cafe.naver.com/dieselmania/30281894?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImRpZXNlbG1hbmlhIiwiYXJ0aWNsZUlkIjozMDI4MTg5NCwiaXNzdWVkQXQiOjE2NTAwMjA5MTEzOTV9.HSkLFEY-rENMmuLVxZZ1NKBO0pFOt1-QMRRttMwRtSU',
#  'https://cafe.naver.com/appleiphone/5599146?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NTk5MTQ2LCJpc3N1ZWRBdCI6MTY1MDAyMDkwMjUwM30.UBWtjWYevzgm9urpbPCdkRsgVzjfUKhGzJ6Q8KhDHAI',
#  'https://cafe.naver.com/inmacbook/2231544?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImlubWFjYm9vayIsImFydGljbGVJZCI6MjIzMTU0NCwiaXNzdWVkQXQiOjE2NTAwMjA5MDY4MTZ9.SdJZqwaclVko5JJE0nTAr521_53W_N_9wrIelA-WtFk',
#  'https://cafe.naver.com/inmacbook/2205961?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImlubWFjYm9vayIsImFydGljbGVJZCI6MjIwNTk2MSwiaXNzdWVkQXQiOjE2NTAwMjA5MDM0MTN9.2N0C_D2gYYnrZGW1pWsZKZWK3ceBM6kYU5bi8PvMrUc',
#  'https://cafe.naver.com/inmacbook/2209402?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImlubWFjYm9vayIsImFydGljbGVJZCI6MjIwOTQwMiwiaXNzdWVkQXQiOjE2NTAwMjA5MDI1MDF9.VPSeBkVRgHhL3EkEmdBfuVQ4mT32TF6XmzQq3jy6wng',
#  'https://cafe.naver.com/appleiphone/5670763?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg==.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo1NjcwNzYzLCJpc3N1ZWRBdCI6MTY1MDAyMDkxMjA0Mn0.O0BpC4cMiYnvk6TjajB-R5-73lCwx4pQ-WSBtBS8XKM']

# %%
#제목, 본문, 댓글, 날짜 빈 list 생성
titles = []
reviews = []
comments = []
time_list = []

#수집한 url 이 담겨있는 a에서 for문 반복
for url in blog_url_list[:10]: #샘플로 슬라이싱 10으로 해둠**
        
    driver.get(url) #해당 url로 이동
    driver.implicitly_wait(30)

    #프레임 전환
    try: 
        driver.switch_to.frame('cafe_main') 
        time.sleep(0.8)
        soup = bs(driver.page_source, 'lxml') 
    
    except UnexpectedAlertPresentException as e:
        pass
        
    # 제목 수집
    try:
        title = soup.find('h3',class_='title_text').text.strip() #제목 찾아서 수집
        titles.append(title)
    except: 
        try:
            title = driver.find_element_by_css_selector('h3.title_text').text.strip() #위 코드가 작동 안하는 경우가 있어서 같은 동작 다른 코드
            titles.append(title)
            time.sleep(0.8)
        except:
            title = [] #위 두개 코드로도 작동이 안되면 빈 리스트로 두고 다음 게시물로 넘어가도록 함
            titles.append(title)   
        
    # 본문 수집
    try:
        content = soup.select_one('div.se-module.se-module-text').text.strip() #본문 찾아서 수집
        reviews.append(content)
    except :
        try:
            content = soup.select_one('div.ContentRenderer').text.strip() #위 코드 작동 안하는 경우가 있어서 다른 코드
            reviews.append(content)
        except :
            try: 
                content = driver.find_element_by_css_selector('div.se-module.se-module-text').text.strip() #위 코드 작동 안하는 경우 대비 다른 코드
                reviews.append(content)
            except :
                try:
                    content = driver.find_element_by_css_selector('div.ContentRenderer').text.strip() #위 코드 작동 안하는 경우 대비 다른 코드
                    reviews.append(content)
                except :
                    content = [] #빈 리스트로 두고 다음 게시물로 넘어가도록 함
                    reviews.append(content)
                     
    # 댓글 수집
    iscomment = soup.find_all('span',class_='text_comment')
    if len(iscomment) != 0: # 댓글이 0개가 아니면 
        box = []
        for i in iscomment:
            box.append([i.get_text()])
    else: # 댓글이 0개면 넘어감
        box = []
        pass
    comments.append(box)
    
    #날짜 수집
    try:
        timeline = driver.find_element_by_xpath("/html/body/div/div/div/div[2]/div[1]/div[2]/div/div[2]/span[1]").text.strip()
        time_list.append(timeline)
    except:
        try:
            timeline = driver.find_element_by_css_selector("#app > div > div > div.ArticleContentBox > div.article_header > div.WriterInfo > div > div.article_info > span.date").text.strip()  
            time_list.append(timeline)
        except:
            timeline= []
            time_list.append(timeline)

# %%
#수집된 제목, 본문, 댓글 확인 
#3개 숫자가 맞아야 dataframe 만들 수 있음
print(len(titles))
print(len(reviews))
print(len(comments))
print(len(time_list))
# Out:
# 10
# 10
# 10
# 10

# %%
#Dataframe 형태로 위에서 수집한 제목, 본문, 댓글을 합쳐줌
data = {'tit' : titles,
        'body' : reviews,
        'comment' : comments,
        'time' : time_list}

dataDF = pd.DataFrame(data)
dataDF
# Out:
#                                tit  \
# 0                            애플워치3
# 1                        애플워치 궁금해요
# 2  애플워치 셀룰러, 단독통화가 되지 않는 다면 확인해보세요
# 3                      애플워치가 제손에!!
# 4                      애플워치 4 에르메스
# 5                        애플워치 사용후기
# 6                      애플워치 배경화면 :
# 7                 애플워치 배터리 실망스럽네요.
# 8                     애플워치3 리퍼받았어요
# 9                     지얄오크 vs 애플워치
#
#                                                 body  \
# 0  애플워치3를 구입하려고 하는데 애플워치에 대해 어떻게 생각하시나요?? 사용하고 계신...
# 1  1.애플워치 추천 (중고 새상품) 부탁드려요 3또는 4 구매가격대 및 구성  스테이...
# 2  1. 흔한 얘기 애플워치 셀룰러라도 연동된 아이폰이 전원이 켜진채 수신,발신이 가능...
# 3  요즘 계속 애플워치에 꽂혀있었거든요ㅠㅠ그런데 큰지출 부담스러워서 가민, 샤오미도 계...
# 4  안녕하세요.현재 사용 중인 애플워치 4 에르메스 입니다. 구입한지는 18년 11월말...
# 5  아이폰 Xs에 에어팟 프로 애플워치 5세대 스댕 물려서 사용중입니다.제가 마지막으로...
# 6  https://en.m.wikipedia.org/wiki/Apple_II애플워치 배...
# 7  원래는 애플워치로 음악만 들으면서 달려서 배터리 별로 신경 안썼는데 1년 정도 쓴 ...
# 8  애플워치3 구입후3월25일 보증완료전에월요일3월2일 워치용두가 뻑뻑하고 잘안돌아가는...
# 9  현재 르로끌 하나 보유중인데 캐주얼 복장에는 잘 안어울리는 것 같아 저렴한 걸로 하...
#
#                                              comment               time
# 0  [[애플워치 좋아요ㅎㅎ 편리하구요 추천합니다], [유튜버분들이 후기 올리신거 보면 ...  2020.03.12. 18:24
# 1  [[저는 2년전에ㅡ애플워치 3 구매해서 현재까지 수영하는데 아무 이상없이 잘 사용하...  2020.01.13. 02:42
# 2  [[애플워치단독모드일때 KT소리샘멘트는 이미 다른글들에 많이 나와있구요 같은상황일때...  2020.02.11. 22:06
# 3  [[우왕 남편분 센스가 👍👍👍알아서 촥촥이네요 애플워치 요새 눈여겨 보는데 🤣], ...  2020.02.04. 22:22
# 4  [[에르메스는 블랙 아니면 4 사는게 진짜 합리적일수도...], [팝니다란 보니깐 ...  2020.02.22. 10:38
# 5  [[애플워치가 비싼데는 다 이유가 있죠. 스마트 워치중에 아직 애플워치에 비빌만한건...  2020.02.07. 00:03
# 6                                 [[신기방기], [감사합니다~]]  2020.03.28. 17:18
# 7  [[너무 빨리닳아요ㅜ], [배터리 교환요], [완충하고 한시간도 안되서 다 닳았다는...  2020.03.17. 03:12
# 8  [[진짜 애플 제품은 처음살때 비싸게 사서 좀 그런데나중에 이렇게 리퍼받는경우 생기...  2020.03.04. 16:35
# 9  [[계속 충전해야 해서 스트레스긴 하지만 기능이 좋지요.], [아이폰 사용하신다면 ...  2020.01.21. 17:59

# %%
#csv로 저장
#dataDF['source'] = 'A' #해당 데이터 표시하기 위해 필요한 정보 추가 할 수 있음. #어떤 카페에서 수집했는지
dataDF['keyword'] = keyword #어떤 키워드로 데이터를 수집했는지 추가
dataDF.to_csv("cafe_view_data.csv", encoding = "utf-8-sig") #한글 인코딩 utf-8-sig 로 하면 안깨짐
dataDF #저장된 모습 확인
# Out:
#                                tit  \
# 0                            애플워치3
# 1                        애플워치 궁금해요
# 2  애플워치 셀룰러, 단독통화가 되지 않는 다면 확인해보세요
# 3                      애플워치가 제손에!!
# 4                      애플워치 4 에르메스
# 5                        애플워치 사용후기
# 6                      애플워치 배경화면 :
# 7                 애플워치 배터리 실망스럽네요.
# 8                     애플워치3 리퍼받았어요
# 9                     지얄오크 vs 애플워치
#
#                                                 body  \
# 0  애플워치3를 구입하려고 하는데 애플워치에 대해 어떻게 생각하시나요?? 사용하고 계신...
# 1  1.애플워치 추천 (중고 새상품) 부탁드려요 3또는 4 구매가격대 및 구성  스테이...
# 2  1. 흔한 얘기 애플워치 셀룰러라도 연동된 아이폰이 전원이 켜진채 수신,발신이 가능...
# 3  요즘 계속 애플워치에 꽂혀있었거든요ㅠㅠ그런데 큰지출 부담스러워서 가민, 샤오미도 계...
# 4  안녕하세요.현재 사용 중인 애플워치 4 에르메스 입니다. 구입한지는 18년 11월말...
# 5  아이폰 Xs에 에어팟 프로 애플워치 5세대 스댕 물려서 사용중입니다.제가 마지막으로...
# 6  https://en.m.wikipedia.org/wiki/Apple_II애플워치 배...
# 7  원래는 애플워치로 음악만 들으면서 달려서 배터리 별로 신경 안썼는데 1년 정도 쓴 ...
# 8  애플워치3 구입후3월25일 보증완료전에월요일3월2일 워치용두가 뻑뻑하고 잘안돌아가는...
# 9  현재 르로끌 하나 보유중인데 캐주얼 복장에는 잘 안어울리는 것 같아 저렴한 걸로 하...
#
#                                              comment               time  \
# 0  [[애플워치 좋아요ㅎㅎ 편리하구요 추천합니다], [유튜버분들이 후기 올리신거 보면 ...  2020.03.12. 18:24
# 1  [[저는 2년전에ㅡ애플워치 3 구매해서 현재까지 수영하는데 아무 이상없이 잘 사용하...  2020.01.13. 02:42
# 2  [[애플워치단독모드일때 KT소리샘멘트는 이미 다른글들에 많이 나와있구요 같은상황일때...  2020.02.11. 22:06
# 3  [[우왕 남편분 센스가 👍👍👍알아서 촥촥이네요 애플워치 요새 눈여겨 보는데 🤣], ...  2020.02.04. 22:22
# 4  [[에르메스는 블랙 아니면 4 사는게 진짜 합리적일수도...], [팝니다란 보니깐 ...  2020.02.22. 10:38
# 5  [[애플워치가 비싼데는 다 이유가 있죠. 스마트 워치중에 아직 애플워치에 비빌만한건...  2020.02.07. 00:03
# 6                                 [[신기방기], [감사합니다~]]  2020.03.28. 17:18
# 7  [[너무 빨리닳아요ㅜ], [배터리 교환요], [완충하고 한시간도 안되서 다 닳았다는...  2020.03.17. 03:12
# 8  [[진짜 애플 제품은 처음살때 비싸게 사서 좀 그런데나중에 이렇게 리퍼받는경우 생기...  2020.03.04. 16:35
# 9  [[계속 충전해야 해서 스트레스긴 하지만 기능이 좋지요.], [아이폰 사용하신다면 ...  2020.01.21. 17:59
#
#   keyword
# 0    애플워치
# 1    애플워치
# 2    애플워치
# 3    애플워치
# 4    애플워치
# 5    애플워치
# 6    애플워치
# 7    애플워치
# 8    애플워치
# 9    애플워치
