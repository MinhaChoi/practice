# %%
import pandas as pd
import numpy as np
import os
import natsort

# %%
path = 'C:\\Users\\mh\\jupyter code\\metaverse_news'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
type(file_list_py[0])
# Out:
# str

# %%
after_order_list = natsort.natsorted(file_list_py)
after_order_list
# Out:
# ['1.csv',
#  '2.csv',
#  '3.csv',
#  '4.csv',
#  '5.csv',
#  '6.csv',
#  '7.csv',
#  '8.csv',
#  '9.csv',
#  '10.csv',
#  '11.csv',
#  '12.csv',
#  '13.csv',
#  '14.csv',
#  '15.csv',
#  '16.csv',
#  '17.csv',
#  '18.csv',
#  '19.csv',
#  '20.csv',
#  '21.csv',
#  '22.csv',
#  '23.csv',
#  '24.csv',
#  '25.csv',
#  '26.csv',
#  '27.csv',
#  '28.csv',
#  '29.csv',
#  '30.csv',
#  '31.csv',
#  '32.csv',
#  '33.csv',
#  '34.csv',
#  '35.csv',
#  '36.csv',
#  '37.csv',
#  '38.csv',
#  '39.csv',
#  '40.csv',
#  '41.csv',
#  '42.csv',
#  '43.csv',
#  '44.csv',
#  '45.csv',
#  '46.csv',
#  '47.csv',
#  '48.csv',
#  '49.csv',
#  '50.csv',
#  '51.csv',
#  '52.csv',
#  '53.csv',
#  '54.csv',
#  '55.csv',
#  '56.csv']

# %%
## csv 파일들을 DataFrame으로 불러와서 concat
df = pd.DataFrame()
for i in after_order_list:
    data = pd.read_csv(i, index_col = 0)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)

# %%
df
# Out:
#                                                     title  \
# 0                                 [대한민국SW대상]주요 전시관-소프트비전관
# 1                                       [자바 개발자 콘퍼런스·전시회]
# 2                               3D 웹의 미래 누가 주도할까「MS? 구글?」
# 3                          안시 청이 말하는 가상공간 비즈니스 성공의 비밀 (2)
# 4                                 세컨드 라이프, 최고의 "사업 계획" 선정
# ...                                                   ...
# 174192  [증권소식] 대신증권, 24년 연속 현금배당…자사주 150만주 취득/장병규 의장, ...
# 174193                 넷마블, 블록체인 생태계 `MBX` 공개…3월 중 정식 서비스
# 174194                   [MWC22]한종희 삼성 부회장 "메타버스 기기 준비 중"
# 174195                  SPC 배스킨라빈스, '메타버스 라이브 커머스' 업계 첫 선
# 174196                 'AI재밍'·'위키윤'이 공약 설명하고 'AI 변상욱'이 보도
#
#                                                       url      journal  \
# 0       https://news.naver.com/main/read.naver?mode=LS...         전자신문
# 1       http://www.etnews.co.kr/news/detail.html?id=20...         전자신문
# 2       https://news.naver.com/main/read.naver?mode=LS...  ZDNet Korea
# 3       http://www.zdnet.co.kr/news/internet/entertain...  ZDNet Korea
# 4       http://www.zdnet.co.kr/news/internet/entertain...  ZDNet Korea
# ...                                                   ...          ...
# 174192  https://www.asiatime.co.kr/article/20220228500324       아시아타임즈
# 174193  http://www.dt.co.kr/contents.html?article_no=2...       디지털타임스
# 174194  http://www.newsis.com/view/?id=NISX20220228_00...          뉴시스
# 174195  https://www.asiatoday.co.kr/view.php?key=20220...       아시아투데이
# 174196  http://www.epnc.co.kr/news/articleView.html?id...         테크월드
#
#                                            time        time2
# 0       [<span class="info">2005.12.01.</span>]  2005.12.01.
# 1       [<span class="info">2006.02.24.</span>]  2006.02.24.
# 2       [<span class="info">2006.05.10.</span>]  2006.05.10.
# 3       [<span class="info">2007.01.03.</span>]  2007.01.03.
# 4       [<span class="info">2007.02.21.</span>]  2007.02.21.
# ...                                         ...          ...
# 174192               <module 'time' (built-in)>       17시간 전
# 174193               <module 'time' (built-in)>       17시간 전
# 174194               <module 'time' (built-in)>       17시간 전
# 174195               <module 'time' (built-in)>       17시간 전
# 174196               <module 'time' (built-in)>       16시간 전
#
# [174197 rows x 5 columns]

# %%
#중복제거
df_new = df.drop_duplicates(subset=None, keep='first', ignore_index=True)
df_new
# Out:
#                                                     title  \
# 0                                 [대한민국SW대상]주요 전시관-소프트비전관
# 1                                       [자바 개발자 콘퍼런스·전시회]
# 2                               3D 웹의 미래 누가 주도할까「MS? 구글?」
# 3                          안시 청이 말하는 가상공간 비즈니스 성공의 비밀 (2)
# 4                                 세컨드 라이프, 최고의 "사업 계획" 선정
# ...                                                   ...
# 158234  [증권소식] 대신증권, 24년 연속 현금배당…자사주 150만주 취득/장병규 의장, ...
# 158235                 넷마블, 블록체인 생태계 `MBX` 공개…3월 중 정식 서비스
# 158236                   [MWC22]한종희 삼성 부회장 "메타버스 기기 준비 중"
# 158237                  SPC 배스킨라빈스, '메타버스 라이브 커머스' 업계 첫 선
# 158238                 'AI재밍'·'위키윤'이 공약 설명하고 'AI 변상욱'이 보도
#
#                                                       url      journal  \
# 0       https://news.naver.com/main/read.naver?mode=LS...         전자신문
# 1       http://www.etnews.co.kr/news/detail.html?id=20...         전자신문
# 2       https://news.naver.com/main/read.naver?mode=LS...  ZDNet Korea
# 3       http://www.zdnet.co.kr/news/internet/entertain...  ZDNet Korea
# 4       http://www.zdnet.co.kr/news/internet/entertain...  ZDNet Korea
# ...                                                   ...          ...
# 158234  https://www.asiatime.co.kr/article/20220228500324       아시아타임즈
# 158235  http://www.dt.co.kr/contents.html?article_no=2...       디지털타임스
# 158236  http://www.newsis.com/view/?id=NISX20220228_00...          뉴시스
# 158237  https://www.asiatoday.co.kr/view.php?key=20220...       아시아투데이
# 158238  http://www.epnc.co.kr/news/articleView.html?id...         테크월드
#
#                                            time        time2
# 0       [<span class="info">2005.12.01.</span>]  2005.12.01.
# 1       [<span class="info">2006.02.24.</span>]  2006.02.24.
# 2       [<span class="info">2006.05.10.</span>]  2006.05.10.
# 3       [<span class="info">2007.01.03.</span>]  2007.01.03.
# 4       [<span class="info">2007.02.21.</span>]  2007.02.21.
# ...                                         ...          ...
# 158234               <module 'time' (built-in)>       17시간 전
# 158235               <module 'time' (built-in)>       17시간 전
# 158236               <module 'time' (built-in)>       17시간 전
# 158237               <module 'time' (built-in)>       17시간 전
# 158238               <module 'time' (built-in)>       16시간 전
#
# [158239 rows x 5 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158239 entries, 0 to 158238
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   title    158239 non-null  object
#  1   url      158239 non-null  object
#  2   journal  158210 non-null  object
#  3   time     158239 non-null  object
#  4   time2    158239 non-null  object
# dtypes: object(5)
# memory usage: 6.0+ MB

# %%
df_new.to_csv('뉴스url수집.csv', encoding = 'utf-8-sig')
