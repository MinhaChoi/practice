# %%
def myfunc(list=[1,2,3,4,5]):
    print(list)

# %%
myfunc(["ge","e"])
# Out:
# ['ge', 'e']

# %%
import pandas as pd
import pickle
import time

# %%
# %%time
df = pd.read_csv('2019_sentence_aspect10.csv', encoding ='utf-8-sig', index_col = 0)
df
# Out:
# Wall time: 7.34 s
#          real_time         day like  \
# 0       2019-09-27  2019-09-27    6
# 1       2019-09-27  2019-09-27    6
# 2       2019-09-27  2019-09-27    6
# 3       2019-08-07  2019-08-07   21
# 4       2019-08-07  2019-08-07   21
# ...            ...         ...  ...
# 488214  2019-07-07  2019-07-07    5
# 488215  2019-07-07  2019-07-07    5
# 488216  2019-07-07  2019-07-07    5
# 488217  2019-07-07  2019-07-07    5
# 488218  2019-07-07  2019-07-07    5
#
#                                                       url  original  \
# 0       https://blog.naver.com/lisa7377?Redirect=Log&l...         0
# 1       https://blog.naver.com/lisa7377?Redirect=Log&l...         0
# 2       https://blog.naver.com/lisa7377?Redirect=Log&l...         0
# 3       https://blog.naver.com/koking9122?Redirect=Log...         2
# 4       https://blog.naver.com/koking9122?Redirect=Log...         2
# ...                                                   ...       ...
# ...

# %%
# %%time
df.to_csv('csv_test.csv', encoding = 'utf-8-sig')
# Out:
# Wall time: 13.1 s

# %%
# %%time
df.to_pickle('pickle_test.pkl')
# Out:
# Wall time: 646 ms

# %%
# %%time
test = pd.read_pickle('pickle_test.pkl')
test
# Out:
# Wall time: 1.67 s
#          real_time         day like  \
# 0       2019-09-27  2019-09-27    6
# 1       2019-09-27  2019-09-27    6
# 2       2019-09-27  2019-09-27    6
# 3       2019-08-07  2019-08-07   21
# 4       2019-08-07  2019-08-07   21
# ...            ...         ...  ...
# 488214  2019-07-07  2019-07-07    5
# 488215  2019-07-07  2019-07-07    5
# 488216  2019-07-07  2019-07-07    5
# 488217  2019-07-07  2019-07-07    5
# 488218  2019-07-07  2019-07-07    5
#
#                                                       url  original  \
# 0       https://blog.naver.com/lisa7377?Redirect=Log&l...         0
# 1       https://blog.naver.com/lisa7377?Redirect=Log&l...         0
# 2       https://blog.naver.com/lisa7377?Redirect=Log&l...         0
# 3       https://blog.naver.com/koking9122?Redirect=Log...         2
# 4       https://blog.naver.com/koking9122?Redirect=Log...         2
# ...                                                   ...       ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488219 entries, 0 to 488218
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   real_time  488219 non-null  object
#  1   day        488219 non-null  object
#  2   like       488219 non-null  object
#  3   url        488219 non-null  object
#  4   original   488219 non-null  int64
#  5   sentence   488219 non-null  object
#  6   0          488219 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 29.8+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488219 entries, 0 to 488218
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   real_time  488219 non-null  object
#  1   day        488219 non-null  object
#  2   like       488219 non-null  object
#  3   url        488219 non-null  object
#  4   original   488219 non-null  int64
#  5   sentence   488219 non-null  object
#  6   0          488219 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 29.8+ MB
